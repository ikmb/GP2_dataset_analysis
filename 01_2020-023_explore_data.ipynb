# %%
import pandas as pd

# %%
#PSC Seren
PSC_ASV_seren = pd.read_csv('./P2N_2020-023_Corinna_Bang/2020-023_16s_Seren_2020_06_Table_ASV_Bayesian_RDP16.tsv', sep='\t', index_col=0)

#PSC Stool
PSC_ASV_stool = pd.read_csv('./P2N_2020-023_Corinna_Bang/2020-023_16s_Stool_2020_06_Table_ASV_Bayesian_RDP16.tsv', sep='\t', index_col=0)


#BSPSPC Seren
BSPSPC_ASV_seren = pd.read_csv('./P2N_2020-023_Corinna_Bang/2020-023_16s_Seren_Table_ASV_Bayesian_RDP16.tsv', sep='\t', index_col=0)


#BSPSPC Stool
BSPSPC_ASV_stool = pd.read_csv('./P2N_2020-023_Corinna_Bang/2020-023_16s_Stool_BSPSPC_Table_ASV_Bayesian_RDP16_renamed.tsv', sep='\t', index_col=0)


#BSPSPC
BSPSPC_data = pd.read_csv('./P2N_2020-023_Corinna_Bang/2020-023_BSPSPC_data.tsv', sep='\t', index_col=0)
BSPSPC_PG2NK_STAMM = pd.read_csv('./P2N_2020-023_Corinna_Bang/2020-023_BSPSPC_PG2NK_STAMM.tsv', sep='\t', index_col=0)

#G2P data
GP2_data_2018 = pd.read_csv('./P2N_2020-023_Corinna_Bang/2020-023_GP2_data_PSC_Seren_2018.tsv', sep='\t', index_col=0)
GP2_data_2020 = pd.read_csv('./P2N_2020-023_Corinna_Bang/2020-023_GP2_data_PSC_Seren_August_2020.tsv', sep='\t', index_col=0)

#PSC
PSC_data = pd.read_csv('./P2N_2020-023_Corinna_Bang/2020-023_PSC_data.tsv', sep='\t', index_col=0)
PSC_STAMM = pd.read_csv('./P2N_2020-023_Corinna_Bang/2020-023_PSC_STAMM.tsv', sep='\t', index_col=0)

# %%
# Load genus level tables
#PSC Seren
PSC_genus_seren = pd.read_csv('./P2N_2020-023_Corinna_Bang/2020-023_16s_Seren_2020_06_Table_Level_6_Genus_Bayesian_RDP16.tsv', sep='\t', index_col=0)

#PSC Stool
PSC_genus_stool = pd.read_csv('./P2N_2020-023_Corinna_Bang/2020-023_16s_Stool_2020_06_Table_Level_6_Genus_Bayesian_RDP16.tsv', sep='\t', index_col=0)


#BSPSPC Seren
BSPSPC_genus_seren = pd.read_csv('./P2N_2020-023_Corinna_Bang/2020-023_16s_Seren_Table_Level_6_Genus_Bayesian_RDP16.tsv', sep='\t', index_col=0)


#BSPSPC Stool
BSPSPC_genus_stool = pd.read_csv('./P2N_2020-023_Corinna_Bang/2020-023_16s_Stool_BSPSPC_Table_Level_6_Genus_Bayesian_RDP16_renamed.tsv', sep='\t', index_col=0)

# %%
PSC_genus_seren
# Out:
#                   phase  G__Flavobacterium  G__Bacillus  G__Massilia  \
# new_id
# 2020-023_PSC_0001    BL               1479          151            0
# 2020-023_PSC_0006    BL               2436          490          269
# 2020-023_PSC_0007    BL               1324         4520         1905
# 2020-023_PSC_0010    BL               1022            0          174
# 2020-023_PSC_0015    BL               1381         6433         2264
# ...                 ...                ...          ...          ...
# 2020-023_PSC_0766    BL               2541          243           79
# 2020-023_PSC_0768    BL                460            0           99
# 2020-023_PSC_0769    BL               1773         6260         2488
# 2020-023_PSC_0775    BL               1587            0          204
# 2020-023_PSC_0781    BL               2001         4601         1889
#
#                    K__Bacteria  G__Propionibacterium  G__Limnohabitans  \
# new_id
# ...

# %%
PSC_genus_stool
# Out:
#                   phase  G__Bacteroides  G__Dialister  G__Alistipes  \
# new_id
# 2020-023_PSC_0001    BL            5195          2091           354
# 2020-023_PSC_0002    BL            8643           480          1179
# 2020-023_PSC_0003    BL            2259             0           549
# 2020-023_PSC_0005    BL            4921           778          2801
# 2020-023_PSC_0006    BL            1757             4          1330
# ...                 ...             ...           ...           ...
# 2020-023_PSC_0778    BL            6110           927          3590
# 2020-023_PSC_0779    BL            6592             0          1222
# 2020-023_PSC_0780    BL            2451           776           873
# 2020-023_PSC_0781    BL            3465          1832          2138
# 2020-023_PSC_0783    BL            3177          1668          1499
#
#                    G__Escherichia.Shigella  G__Subdoligranulum  \
# new_id
# 2020-023_PSC_0001                        0                 186
# ...

# %%
BSPSPC_ASV_seren
# Out:
#                   phase  ASV_1  ASV_2  ASV_3  ASV_4  ASV_5  ASV_6  ASV_7  \
# new_id
# 2020-023_BSP_0011    F2      2      0      0      0      0      0      0
# 2020-023_BSP_0041    F2    268      0    159      0    189      0      0
# 2020-023_BSP_0055    F2      0      0      0      0    912      0      0
# 2020-023_BSP_0096    F2    989      0   2555      0      0      0      0
# 2020-023_BSP_0119    F2    777      0   3190      0    958      0      0
# ...                 ...    ...    ...    ...    ...    ...    ...    ...
# 2020-023_SPC_0409    F2    225      0    202      0    422      0      0
# 2020-023_SPC_0480    F2      0      0    659      0    756      0      0
# 2020-023_SPC_0515    F2    782      0    699      0    482      0    163
# 2020-023_SPC_0726    F2      0    817    569      0    705      0      0
# 2020-023_SPC_0741    F2     47      0    100      0     31      0      0
#
#                    ASV_8  ASV_9  ...  ASV_23143  ASV_23144  ASV_23145  \
# ...

# %%
BSPSPC_ASV_stool
# Out:
#                   phase  ASV_1  ASV_2  ASV_3  ASV_4  ASV_5  ASV_6  ASV_7  \
# new_id
# 2020-023_BSP_0011    F2    469      0   2235   1506      0      0     89
# 2020-023_BSP_0041    F2    227    384      0      0      0    468    228
# 2020-023_BSP_0055    F2    660      0      0    380     53    162      0
# 2020-023_BSP_0096    F2    303    547    365    456      0      0      0
# 2020-023_BSP_0119    F2    198     66    305    274    235    138      0
# 2020-023_BSP_0132    F2    114    114    114     38      0      0     14
# 2020-023_BSP_0173    F2      0    512   1009    133      0     86      0
# 2020-023_BSP_0198    F2    721   1198   1214    823      0    352    149
# 2020-023_BSP_0217    F2   5370      0      0    366   9004      0    135
# 2020-023_BSP_0249    F2    119    127    287    376      0     68    227
# 2020-023_BSP_0253    F2   1506    153    403    646      0      0    688
# 2020-023_BSP_0261    F2      0    647   1421      0      0    194    373
# ...

# %%
BSPSPC_data
# Out:
#                    t5_year_of_birth_F2  t24_height_F2  t25_height_F2  \
# new_id
# 2020-023_BSP_0011                 1971            184          184.8
# 2020-023_BSP_0041                 1960            155          153.5
# 2020-023_BSP_0055                 1970            190          191.0
# 2020-023_BSP_0096                 1961            184          183.6
# 2020-023_BSP_0119                 1968            185          185.2
# 2020-023_BSP_0132                 1957            183          181.3
# 2020-023_BSP_0173                 1958            173          173.7
# 2020-023_BSP_0198                 1976            182          183.4
# 2020-023_BSP_0217                 1977            190          191.5
# 2020-023_BSP_0249                 1969            175          176.2
# 2020-023_BSP_0253                 1967            183          186.1
# 2020-023_BSP_0261                 1962            164          164.2
# ...

# %%
BSPSPC_PG2NK_STAMM
# Out:
#                    revision_F2  sex_F2 geb_dat_mod_F2
# new_id
# 2020-023_BSP_0011            1       1     1971-04-01
# 2020-023_BSP_0041            1       2     1960-07-01
# 2020-023_BSP_0055            1       1     1970-09-01
# 2020-023_BSP_0096            1       1     1961-04-01
# 2020-023_BSP_0119            1       1     1968-04-01
# 2020-023_BSP_0132            1       1     1957-09-01
# 2020-023_BSP_0173         1001       2     1958-09-01
# 2020-023_BSP_0198            1       1     1976-08-01
# 2020-023_BSP_0217         1001       1     1977-02-01
# 2020-023_BSP_0249            1       1     1969-08-01
# 2020-023_BSP_0253            1       1     1967-05-01
# 2020-023_BSP_0296            1       1     1957-04-01
# 2020-023_BSP_0312            1       2     1972-05-01
# 2020-023_BSP_0327         1001       1     1973-02-01
# 2020-023_BSP_0348            1       2     1970-10-01
# 2020-023_BSP_0361            1       2     1966-12-01
# ...

# %%
GP2_data_2018
# Out:
#                    GP»_Iso_1_IgG OD  GP»_Iso_1_IgG _U/ml  GP2_Iso_1_IgA_OD  \
# new_id
# 2020-023_PSC_0001             0.275               13.565             0.200
# 2020-023_PSC_0003             0.143                9.223             0.041
# 2020-023_PSC_0010             0.088                2.960             0.076
# 2020-023_PSC_0022             0.108                4.513             0.190
# 2020-023_PSC_0024             0.236               10.978             0.275
# ...                             ...                  ...               ...
# 2020-023_PSC_0770             0.389               19.204             0.096
# 2020-023_PSC_0771             0.204                9.335             0.278
# 2020-023_PSC_0773             0.153                6.758             0.234
# 2020-023_PSC_0774             0.308               15.678             0.210
# 2020-023_PSC_0783             0.209                9.591             0.067
#
# ...

# %%
data_PSC_Seren_August_2020
# Out:
#                   phase a-GP2 I1 IgA_7 U/ml a-GP2 I1 IgG_33 U/ml  \
# new_id
# 2020-023_BSP_0011    F2                1,05                 2,06
# 2020-023_BSP_0041    F2                1,31                 1,74
# 2020-023_BSP_0055    F2               < min                  1,9
# 2020-023_BSP_0096    F2                1,67                 4,19
# 2020-023_BSP_0119    F2               < min                 1,35
# ...                 ...                 ...                  ...
# 2020-023_SPC_0409    F2               < min                 1,35
# 2020-023_SPC_0480    F2                1,95                10,38
# 2020-023_SPC_0515    F2                1,46                11,27
# 2020-023_SPC_0726    F2                1,47                  2,6
# 2020-023_SPC_0741    F2               < min                 1,27
#
#                   a-GP2 I4 IgA_9 U/ml a-GP2 I4 IgG_23 U/ml a-PR3 hs_15 U/ml
# new_id
# 2020-023_BSP_0011                4,03                 3,61             1,86
# ...

# %%
PSC_data
# Out:
#                    t5_year_of_birth_BL  t24_height_BL  t27_weight_BL  \
# new_id
# 2020-023_PSC_0001               1955.0          165.0           61.0
# 2020-023_PSC_0002               1963.0          174.0           61.0
# 2020-023_PSC_0003               1983.0          171.0           79.0
# 2020-023_PSC_0004               1999.0          183.0           70.0
# 2020-023_PSC_0005               1940.0          165.0           63.0
# ...                                ...            ...            ...
# 2020-023_PSC_0780               1989.0          180.0           86.0
# 2020-023_PSC_0781               1951.0          159.0           62.0
# 2020-023_PSC_0782               1985.0          169.0           64.0
# 2020-023_PSC_0783               1956.0          165.0           62.0
# 2020-023_PSC_0784               1959.0          159.0           72.0
#
#                    t37_sample_age_BL  t38_smoke_cigarettes_n_BL  \
# new_id
# ...

# %%
PSC_STAMM
# Out:
#                    revision  sex     geb_dat
# new_id
# 2020-023_PSC_0001         1  2.0  1955-04-01
# 2020-023_PSC_0002         1  2.0  1963-09-01
# 2020-023_PSC_0003         1  2.0  1983-01-01
# 2020-023_PSC_0006         1  2.0  1943-03-01
# 2020-023_PSC_0007         1  2.0  1979-07-01
# ...                     ...  ...         ...
# 2020-023_PSC_0781         1  2.0  1951-11-01
# 2020-023_PSC_0782         1  2.0  1985-02-01
# 2020-023_PSC_0783         1  2.0  1956-05-01
# 2020-023_PSC_0783         1  2.0  1956-05-01
# 2020-023_PSC_0784      1001  2.0  1959-08-01
#
# [551 rows x 3 columns]

# %% [markdown]
# # Subset count tables and meta

# %% [markdown]
# ## GP2 meta

# %%
# split and merge GP2 data by disease group 
GP2_data_BSPSPC = GP2_data_2020[~GP2_data_2020.index.str.contains('PSC')]

# %%
GP2_data_BSPSPC
# Out:
#                   phase a-GP2 I1 IgA_7 U/ml a-GP2 I1 IgG_33 U/ml  \
# new_id
# 2020-023_BSP_0011    F2                1,05                 2,06
# 2020-023_BSP_0041    F2                1,31                 1,74
# 2020-023_BSP_0055    F2               < min                  1,9
# 2020-023_BSP_0096    F2                1,67                 4,19
# 2020-023_BSP_0119    F2               < min                 1,35
# 2020-023_BSP_0132    F2                1,37                 2,43
# 2020-023_BSP_0173    F2                1,37                  2,3
# 2020-023_BSP_0198    F2                 3,5                13,92
# 2020-023_BSP_0217    F2                1,66                 1,66
# 2020-023_BSP_0249    F2                1,96                 3,94
# 2020-023_BSP_0253    F2                6,88                 1,86
# 2020-023_BSP_0261    F2                1,41                 3,28
# 2020-023_BSP_0296    F2                1,02                 2,55
# ...

# %%
GP2_data_BSPSPC = GP2_data_BSPSPC.drop('phase', axis=1)

# %%
GP2_data_BSPSPC = GP2_data_BSPSPC.rename(columns={
    'a-GP2 I1 IgA_7 U/ml': 'GP2_Iso1_IgA',
    'a-GP2 I1 IgG_33 U/ml': 'GP2_Iso1_IgG',
    'a-GP2 I4 IgA_9 U/ml': 'GP2_Iso4_IgA',
    'a-GP2 I4 IgG_23 U/ml': 'GP2_Iso4_IgG',
    'a-PR3 hs_15 U/ml': 'PR3'
 })

# %%
for column in GP2_data_BSPSPC.columns:
    GP2_data_BSPSPC[column] = GP2_data_BSPSPC[column].str.replace(',', '.')

# %%
# Replace "< min" with 0 in the DataFrame
GP2_data_BSPSPC = GP2_data_BSPSPC.replace("< min", 0).astype(float)

# %%
GP2_data_BSPSPC
# Out:
#                    GP2_Iso1_IgA  GP2_Iso1_IgG  GP2_Iso4_IgA  GP2_Iso4_IgG  \
# new_id
# 2020-023_BSP_0011          1.05          2.06          4.03          3.61
# 2020-023_BSP_0041          1.31          1.74          1.10          1.91
# 2020-023_BSP_0055          0.00          1.90          1.77          3.56
# 2020-023_BSP_0096          1.67          4.19          1.95          3.91
# 2020-023_BSP_0119          0.00          1.35          1.32          2.45
# 2020-023_BSP_0132          1.37          2.43          2.34          4.08
# 2020-023_BSP_0173          1.37          2.30          2.86          4.03
# 2020-023_BSP_0198          3.50         13.92          3.31          6.48
# 2020-023_BSP_0217          1.66          1.66          1.77          5.60
# 2020-023_BSP_0249          1.96          3.94          5.88          7.04
# 2020-023_BSP_0253          6.88          1.86          4.74          2.83
# 2020-023_BSP_0261          1.41          3.28          3.62          3.43
# ...

# %%
GP2_data_PSC_2 = GP2_data_2020[GP2_data_2020.index.str.contains('PSC')]

# %%
GP2_data_PSC_2
# Out:
#                   phase a-GP2 I1 IgA_7 U/ml a-GP2 I1 IgG_33 U/ml  \
# new_id
# 2020-023_PSC_0002    BL                7,14                 3,38
# 2020-023_PSC_0004    BL               < min                < min
# 2020-023_PSC_0005    BL               < min                < min
# 2020-023_PSC_0006    BL                1,34                 2,64
# 2020-023_PSC_0007    BL                3,28                10,06
# ...                 ...                 ...                  ...
# 2020-023_PSC_0779    BL                4,43                 5,76
# 2020-023_PSC_0780    BL               < min                 1,75
# 2020-023_PSC_0781    BL                1,08                23,03
# 2020-023_PSC_0782    BL                1,26                  1,4
# 2020-023_PSC_0784    BL               < min                < min
#
#                   a-GP2 I4 IgA_9 U/ml a-GP2 I4 IgG_23 U/ml a-PR3 hs_15 U/ml
# new_id
# 2020-023_PSC_0002                3,84                 4,72             7,22
# ...

# %%
GP2_data_2018.columns
# Out:
# Index(['GP»_Iso_1_IgG OD', 'GP»_Iso_1_IgG _U/ml', 'GP2_Iso_1_IgA_OD',
#        'GP2_Iso_1_IgA _U/ml', 'GP2_3850_Iso_4 IgG_OD',
#        'GP2_3850_Iso_4 IgG_U/ml', 'GP2_3750_Iso_4 IgA_OD',
#        'GP2_3750_Iso_4 IgA _U/ml', 'Diagnosis', 'QUANTA Flash PR3 CIA (RLU)',
#        'QUANTA Flash PR3 CIA (CU)',
#        'QUANTA Flash PR3 CIA (CU)- (<2.3 entered as 2.2)'],
#       dtype='object')

# %%
# drop measurments with density
GP2_data_PSC_1 = GP2_data_2018[['GP»_Iso_1_IgG _U/ml', 'GP2_Iso_1_IgA _U/ml', 'GP2_3850_Iso_4 IgG_U/ml', 'GP2_3750_Iso_4 IgA _U/ml', 'QUANTA Flash PR3 CIA (CU)- (<2.3 entered as 2.2)']]

# %%
# rename the columns
GP2_data_PSC_1 = GP2_data_PSC_1.rename(columns={
    'GP»_Iso_1_IgG _U/ml': 'GP2_Iso1_IgG',
    'GP2_Iso_1_IgA _U/ml': 'GP2_Iso1_IgA',
    'GP2_3850_Iso_4 IgG_U/ml': 'GP2_Iso4_IgG',
    'GP2_3750_Iso_4 IgA _U/ml': 'GP2_Iso4_IgA',
    'QUANTA Flash PR3 CIA (CU)- (<2.3 entered as 2.2)': 'PR3'
})

# %%
GP2_data_PSC_2 = GP2_data_PSC_2.rename(columns={
    'a-GP2 I1 IgA_7 U/ml': 'GP2_Iso1_IgA',
    'a-GP2 I1 IgG_33 U/ml': 'GP2_Iso1_IgG',
    'a-GP2 I4 IgA_9 U/ml': 'GP2_Iso4_IgA',
    'a-GP2 I4 IgG_23 U/ml': 'GP2_Iso4_IgG',
    'a-PR3 hs_15 U/ml': 'PR3'
 })

# %%
GP2_data_PSC_2 = GP2_data_PSC_2.drop('phase', axis=1)

# %%
for column in GP2_data_PSC_2.columns:
    GP2_data_PSC_2[column] = GP2_data_PSC_2[column].str.replace(',', '.')

# %%
# Replace "< min" with 0 in the DataFrame
GP2_data_PSC_2 = GP2_data_PSC_2.replace("< min", 0).astype(float)

# %%
GP2_data_PSC_2
# Out:
#                    GP2_Iso1_IgA  GP2_Iso1_IgG  GP2_Iso4_IgA  GP2_Iso4_IgG  \
# new_id
# 2020-023_PSC_0002          7.14          3.38          3.84          4.72
# 2020-023_PSC_0004          0.00          0.00          0.00          1.76
# 2020-023_PSC_0005          0.00          0.00          1.04          1.39
# 2020-023_PSC_0006          1.34          2.64          1.41          3.03
# 2020-023_PSC_0007          3.28         10.06          3.55         14.37
# ...                         ...           ...           ...           ...
# 2020-023_PSC_0779          4.43          5.76          2.74          5.32
# 2020-023_PSC_0780          0.00          1.75          0.00          4.69
# 2020-023_PSC_0781          1.08         23.03          2.24          9.16
# 2020-023_PSC_0782          1.26          1.40          3.19          2.55
# 2020-023_PSC_0784          0.00          0.00          1.32          3.64
#
#                     PR3
# new_id
# 2020-023_PSC_0002  7.22
# ...

# %%
GP2_data_PSC_1
# Out:
#                    GP2_Iso1_IgG  GP2_Iso1_IgA  GP2_Iso4_IgG  GP2_Iso4_IgA  \
# new_id
# 2020-023_PSC_0001        13.565         8.394         6.012         7.953
# 2020-023_PSC_0003         9.223         1.569         1.260         0.900
# 2020-023_PSC_0010         2.960         1.600         0.749         0.915
# 2020-023_PSC_0022         4.513         8.238         2.030        12.275
# 2020-023_PSC_0024        10.978        12.949         5.973        11.817
# ...                         ...           ...           ...           ...
# 2020-023_PSC_0770        19.204         3.114        12.128         2.445
# 2020-023_PSC_0771         9.335        13.117         2.564         4.402
# 2020-023_PSC_0773         6.758        10.664         1.461         2.228
# 2020-023_PSC_0774        15.678         8.947         3.724         3.464
# 2020-023_PSC_0783         9.591         1.542         4.687         1.433
#
#                     PR3
# new_id
# 2020-023_PSC_0001   2.2
# ...

# %%
GP2_data_PSC = pd.concat([GP2_data_PSC_1, GP2_data_PSC_2], axis=0)

# %%
# Check the data types of the DataFrame
print(GP2_data_PSC.dtypes)
# Out:
# GP2_Iso1_IgG    float64
# GP2_Iso1_IgA    float64
# GP2_Iso4_IgG    float64
# GP2_Iso4_IgA    float64
# PR3             float64
# dtype: object

# %%
GP2_data_PSC
# Out:
#                    GP2_Iso1_IgG  GP2_Iso1_IgA  GP2_Iso4_IgG  GP2_Iso4_IgA  \
# new_id
# 2020-023_PSC_0001        13.565         8.394         6.012         7.953
# 2020-023_PSC_0003         9.223         1.569         1.260         0.900
# 2020-023_PSC_0010         2.960         1.600         0.749         0.915
# 2020-023_PSC_0022         4.513         8.238         2.030        12.275
# 2020-023_PSC_0024        10.978        12.949         5.973        11.817
# ...                         ...           ...           ...           ...
# 2020-023_PSC_0779         5.760         4.430         5.320         2.740
# 2020-023_PSC_0780         1.750         0.000         4.690         0.000
# 2020-023_PSC_0781        23.030         1.080         9.160         2.240
# 2020-023_PSC_0782         1.400         1.260         2.550         3.190
# 2020-023_PSC_0784         0.000         0.000         3.640         1.320
#
#                      PR3
# new_id
# 2020-023_PSC_0001   2.20
# ...

# %% [markdown]
# ## PSC

# %%
# Subset PSC_ASV_seren and GP2_data_PSC by the index of PSC_ASV_stool
PSC_ASV_seren = PSC_ASV_seren[PSC_ASV_seren.index.isin(PSC_ASV_stool.index)]
GP2_data_PSC = GP2_data_PSC[GP2_data_PSC.index.isin(PSC_ASV_stool.index)]

# %%
# Check if all index values in PSC_ASV_stool exist in GP2_data_PSC
index_check = PSC_ASV_stool.index.isin(GP2_data_PSC.index)
all_correspond = index_check.all()

# %%
GP2_data_PSC
# Out:
#                    GP2_Iso1_IgG  GP2_Iso1_IgA  GP2_Iso4_IgG  GP2_Iso4_IgA  \
# new_id
# 2020-023_PSC_0001           NaN           NaN           NaN           NaN
# 2020-023_PSC_0003           NaN           NaN           NaN           NaN
# 2020-023_PSC_0010           NaN           NaN           NaN           NaN
# 2020-023_PSC_0022           NaN           NaN           NaN           NaN
# 2020-023_PSC_0024           NaN           NaN           NaN           NaN
# ...                         ...           ...           ...           ...
# 2020-023_PSC_0775         282.0         112.0         558.0          29.0
# 2020-023_PSC_0778         116.0           NaN         795.0         211.0
# 2020-023_PSC_0779         576.0         443.0         532.0         274.0
# 2020-023_PSC_0780         175.0           NaN         469.0           NaN
# 2020-023_PSC_0781        2303.0         108.0         916.0         224.0
#
#                      PR3
# new_id
# 2020-023_PSC_0001    NaN
# ...

# %%
PSC_ASV_seren.to_csv('./results/PSC_ASV_seren.csv', index=True)
PSC_ASV_stool.to_csv('./results/PSC_ASV_stool.csv', index=True)

# %%
GP2_data_PSC.to_csv('./results/GP2_data_PSC.csv', index=True)

# %% [markdown]
# ### for genus

# %%
# Subset PSC_ASV_seren and GP2_data_PSC by the index of PSC_ASV_stool
PSC_genus_seren = PSC_ASV_seren[PSC_genus_seren.index.isin(PSC_genus_stool.index)]

# %%
PSC_genus_seren.to_csv('./results/PSC_genus_seren.csv', index=True)
PSC_genus_stool.to_csv('./results/PSC_genus_stool.csv', index=True)

# %% [markdown]
# ## BSPSPC

# %%
# Subset BSPSPC_ASV_seren and GP2_data_BSPSPC by the index of BSPSPC_ASV_stool
BSPSPC_ASV_seren = BSPSPC_ASV_seren[BSPSPC_ASV_seren.index.isin(BSPSPC_ASV_stool.index)]
GP2_data_BSPSPC = GP2_data_BSPSPC[GP2_data_BSPSPC.index.isin(BSPSPC_ASV_stool.index)]

# %%
# Check if all index values in PSC_ASV_stool exist in GP2_data_PSC
index_check = BSPSPC_ASV_stool.index.isin(GP2_data_BSPSPC.index)
all_correspond = index_check.all()

# %%
all_correspond
# Out:
# True

# %%
BSPSPC_ASV_seren.to_csv('./results/BSPSPC_ASV_seren.csv', index=True)
BSPSPC_ASV_stool.to_csv('./results/BSPSPC_ASV_stool.csv', index=True)

# %%
GP2_data_BSPSPC.to_csv('./results/GP2_data_BSPSPC.csv', index=True)

# %% [markdown]
# ### for genus

# %%
BSPSPC_genus_seren = BSPSPC_genus_seren[BSPSPC_genus_seren.index.isin(BSPSPC_genus_stool.index)]

# %%
BSPSPC_genus_seren.to_csv('./results/BSPSPC_genus_seren.csv', index=True)
BSPSPC_genus_stool.to_csv('./results/BSPSPC_genus_stool.csv', index=True)
